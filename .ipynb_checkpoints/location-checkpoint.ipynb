# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\Atharv\Documents\Capstone Project\location_table_cleaned.csv")
dataset.head(3)
# Out:
#         State    District                  City
# 0   Rajasthan  Ganganagar                 1 SGM
# 1   Rajasthan  Ganganagar                 3 STR
# 2  Tamil Nadu  Coimbatore  A.Thirumuruganpoondi

# %%
dataset.shape

# %%
dataset.isnull().sum()
# Out:
# State       0
# District    0
# City        0
# dtype: int64

# %%
dataset.notnull().sum()
# Out:
# State       5134
# District    5134
# City        5134
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()
